# %%
from matplotlib import pyplot as plt

# %%
x = [1,4,9,16,25,36,49,64]

# %%
plt.plot(x, color = 'r')

# %%
plt.plot(x, 'or')

# %%
y = [i for i in range(1,9)]

# %%
y
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.plot(x,y)

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('matplotlib sample')
# Out:
# Text(0.5, 1.0, 'matplotlib sample')

# %%
plt.plot('x,y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('matplotlib sample')
# Out:
# Text(0.5, 1.0, 'matplotlib sample')

# %%
x
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
y
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.plot('x, y')

# %%
plt.plot(x,y, color = 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('matplotlib sample', color = 'r')
# Out:
# Text(0.5, 1.0, 'matplotlib sample')

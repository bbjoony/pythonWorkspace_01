# %%
import pandas as pd

# %%
import re, os

# %%
df = pd.read_csv('apt_comma.csv', encoding = 'cp949')

# %%
df
# Out:
#                 시군구         단지명        면적    계약년월  계약일      가격   층  건축년도  \
# 0       강원도 강릉시 견소동        송정한신   84.9450  202002    2  15,700  12  1997
# 1       강원도 강릉시 견소동        송정한신   84.9450  202002    5  13,500   5  1997
# 2       강원도 강릉시 견소동        송정한신   59.8000  202002    5  11,500  13  1997
# 3       강원도 강릉시 견소동        송정한신  116.1750  202002    6  20,000   6  1997
# 4       강원도 강릉시 견소동        송정한신   84.9450  202002    7  14,000   7  1997
# ...             ...         ...       ...     ...  ...     ...  ..   ...
# 73147  충청북도 충주시 호암동       호암동수채   84.9289  202002   27  17,500   2  2007
# 73148  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002    6  14,500   3  2002
# 73149  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002    8  14,500  10  2002
# 73150  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002   11  13,800  12  2002
# 73151  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002   13  12,000  12  2002
#
#                도로명
# 0      경강로2539번길 8
# 1      경강로2539번길 8
# 2      경강로2539번길 8
# ...

# %%
df.가격 = df.가격.str.replace(',','').astype('int64')

# %%
df
# Out:
#                 시군구         단지명        면적    계약년월  계약일     가격   층  건축년도  \
# 0       강원도 강릉시 견소동        송정한신   84.9450  202002    2  15700  12  1997
# 1       강원도 강릉시 견소동        송정한신   84.9450  202002    5  13500   5  1997
# 2       강원도 강릉시 견소동        송정한신   59.8000  202002    5  11500  13  1997
# 3       강원도 강릉시 견소동        송정한신  116.1750  202002    6  20000   6  1997
# 4       강원도 강릉시 견소동        송정한신   84.9450  202002    7  14000   7  1997
# ...             ...         ...       ...     ...  ...    ...  ..   ...
# 73147  충청북도 충주시 호암동       호암동수채   84.9289  202002   27  17500   2  2007
# 73148  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002    6  14500   3  2002
# 73149  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002    8  14500  10  2002
# 73150  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002   11  13800  12  2002
# 73151  충청북도 충주시 호암동  호암리버빌(1단지)   84.6800  202002   13  12000  12  2002
#
#                도로명
# 0      경강로2539번길 8
# 1      경강로2539번길 8
# 2      경강로2539번길 8
# 3      경강로2539번길 8
# ...
